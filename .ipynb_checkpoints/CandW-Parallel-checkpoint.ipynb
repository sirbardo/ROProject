# %% [markdown]
# #RO Project#
#
# 1. Read instances' data from file
# 2. Initialize the parameters read from file
# 3. n = number of customers
# 4. c = matrix of costs
# 5. ml = max load of the vehicle
# 6. l = linehaul values vector
# 7. b = backhaul values vector
# 8. Initialize the matrix s of savings
# 9. for i = 1:n
#     1. for j = 1:n
#         1. If i == j
#             1. s_ij = +inf
#         2. else
#             1. s_ij = c_i0 + c_0j - c_ij
# 10. Routes = list of empty routes
# 11. for i = 1:n
#     1. Routes_i = (0,i,0)
# 12. Order the savings s in a non increasing fashion
# 13. for each route in Routes:
#     1. while this route can be feasibly (respecting the constraints) merged further:
# 	   1.determine the first saving s_ki or s_jl in the ordered list that can feasibly be used to merge the current route with another route containing either the arc (k, 0) or (0, l).
#        	   2. merge the two routes.

# %%
import numpy as np
import sys

# %%
filename = 'Instances/A1.txt'
with open(filename, 'r') as f:
    content = f.read()
    print(content)
# Out:
# 25
# 1
# 8
# 12000   16000   0   1550
# 9795   21510   0   549   0
# 7758   10895   0   558   0
# 12927   2464   0   851   0
# 23286   5538   0   388   0
# 7416   15826   0   194   0
# 21524   24879   483   0   0
# 22337   17915   389   0   0
# 7642   9722   435   0   0
# 3707   20036   452   0   0
# 15492   2721   343   0   0
# 12430   10638   444   0   0
# 13595   1918   350   0   0
# 4290   2721   307   0   0
# 18684   5268   810   0   0
# 8686   9546   1002   0   0
# 23140   10989   476   0   0
# 5263   14289   674   0   0
# 19557   17564   691   0   0
# 23281   29684   675   0   0
# 374   22683   410   0   0
# 18804   9082   351   0   0
# 5444   25004   786   0   0
# 20390   25745   59   0   0
# 4310   21692   362   0   0
# 8526   2495   550   0   0

# %%
content = content.split('\n')[0:-1] #-1 because the last element is a newline, so we skip it

# %%
n_of_customers = int(content[0])
n_of_vehicles = int(content[2])
capacity = int(content[3].split()[3])
linehaul_vector = [0] + [int(i.split()[2]) for i in content[4:]] #linehaul data is in the fourth column
backhaul_vector = [0] + [int(i.split()[3]) for i in content[4:]] #and backhaul is in the third

# %%
import math

def euclidean_distance2D(point1, point2):
    
    x1, y1 = point1
    x2, y2 = point2
    
    return (math.sqrt((x1-x2)**2 + (y1-y2)**2))

# %%
cost_matrix = []

x_coords = [int(i.split()[0]) for i in content[3:]]
y_coords = [int(i.split()[1]) for i in content[3:]]

for i, (x1, y1) in enumerate(zip(x_coords, y_coords)): #could also enumerate over y_coords, the dimensions are equal
    
    current_row = []
    
    for j, (x2, y2) in enumerate(zip(x_coords, y_coords)):
        
        current_row += [euclidean_distance2D((x1,y1), (x2,y2))]
        
    cost_matrix += [current_row]

# %%
cost_matrix = np.array(cost_matrix)
savings_matrix = np.zeros((n_of_customers+1, n_of_customers+1))

# %%
for i in range(n_of_customers+1):
    for j in range(n_of_customers+1):
        if (i==j):
            savings_matrix[i][j] = sys.maxsize
        else:
            savings_matrix[i][j] = cost_matrix[i][0] + cost_matrix[0][j] - cost_matrix[i][j]

# %%
routes = []

for i in range(n_of_customers):
    
    routes += [(0, i+1, 0)]

# %%
cost_matrix.shape
# Out:
# (26, 26)

# %%
ordered_savings = []

for (i, j), el in np.ndenumerate(savings_matrix):
    ordered_savings += [(el, (i, j))]

ordered_savings.sort(key=lambda x: x[0], reverse=True)
ordered_i_savings = list(ordered_savings)
ordered_j_savings = list(ordered_savings)
ordered_i_savings.sort(key=lambda x: (x[1][0], -x[0]))
ordered_j_savings.sort(key=lambda x: (x[1][1], -x[0]))

# %%
def is_route_merge_valid(id_route1, id_route2):
    
    """First, try if you can merge it with the end of route1 to end of route2"""
        
    possible_route = list( routes[id_route1][:-1] + routes[id_route2][1:]) #the merge itself is just skipping the left and right
    
    i = 0
    
    
    cost_of_possible_route_backhaul = 0
    cost_of_possible_route_linehaul = 0
    is_right_possible = True
    
    for node_touched in possible_route[1:-1]:
        
        if linehaul_vector[node_touched] == 0:#linehaul_vector is 0 if a node is not a linehaul node, so we have to go to the next for
            break
        else:
            cost_of_possible_route_linehaul += linehaul_vector[node_touched]
            i+=1
            
    starting_point = i
    if i < len(possible_route[1:-1]):
        for node_touched in possible_route[starting_point+1:-1]:
            
            if backhaul_vector[node_touched] == 0 and i != len(possible_route): #we are trying to linehaul AFTER we started backhauling... constraint broken:
                is_right_possible = False
                #print(i, backhaul_vector[node_touched], node_touched)
            else:
                cost_of_possible_route_backhaul += backhaul_vector[node_touched]
                i+=1
                
        
    if (cost_of_possible_route_backhaul > capacity or cost_of_possible_route_linehaul > capacity):
        is_right_possible = False
        
    if (cost_of_possible_route_linehaul == 0): # we are only backhauling
        is_right_possible = False

        
    """Now the other possible route."""
        
    possible_route = list( routes[id_route2][:-1] + routes[id_route1][1:]) #the merge itself is just skipping the left and right
    
    i = 0
    
    cost_of_possible_route_backhaul = 0
    cost_of_possible_route_linehaul = 0
    is_left_possible = True
    
    for node_touched in possible_route[1:-1]:
        
        if linehaul_vector[node_touched] == 0:#linehaul_vector is 0 if a node is not a linehaul node, so we have to go to the next for
            break
        else:
            cost_of_possible_route_linehaul += linehaul_vector[node_touched]
            i+=1
            
    starting_point = i
    if i < len(possible_route[1:-1]):
        for node_touched in possible_route[starting_point+1:-1]:
            
            if backhaul_vector[node_touched] == 0 and i != len(possible_route): #we are trying to linehaul AFTER we started backhauling... constraint broken:
                is_left_possible = False
            else:
                cost_of_possible_route_backhaul += backhaul_vector[node_touched]
                i+=1
                
        
    if (cost_of_possible_route_backhaul > capacity or cost_of_possible_route_linehaul > capacity):
        is_left_possible = False
        
    if (cost_of_possible_route_linehaul == 0): # we are only backhauling
        is_left_possible = False

        
    #print(is_left_possible, is_right_possible)
        
    if not is_left_possible and not is_right_possible:
        return ('')
    elif is_left_possible and is_right_possible:
        return ('lr')
    elif is_left_possible:
        return 'l'
    else:
        return 'r'

# %%
def merge_two_routes(id_route, found_id, direction_of_merge):

    if id_route== found_id:
        return
    
    tmp_list1 = list(routes[id_route])
    tmp_list2 = list(routes[found_id])
        
    tmp_list1.pop(0)
    tmp_list1.pop(-1)
    tmp_list2.pop(0)
    tmp_list2.pop(-1)
    
    if direction_of_merge == 'l':
        
        routes[id_route] = tuple([0]+tmp_list2+tmp_list1+[0])
    
    if direction_of_merge == 'r':
        
        routes[id_route] = tuple([0]+tmp_list1+tmp_list2+[0])
    
    routes[found_id] = (-1,-1,-1)

# %%
direction_of_merge = is_route_merge_valid(10, 18)
print(direction_of_merge)
# Out:
# lr

# %%
def there_is_a_possible_merge(i, j):
    
    
    for id1, route1 in enumerate(routes):
        
        for id2, route2 in enumerate(routes):
            
            if route1 == (-1, -1, -1) or route2 == (-1, -1, -1):
                continue
                
            if (id1 != id2):
                
                if (route1[1] == j and route2[-2] == i):
                    
                    return (id1, id2)
    
    return -1

# %%
for idx, saving in enumerate(ordered_savings[26:]): # '26:' because we are not interested in the infinite savings, since their i,j pairs won't allow feasible merges
    
    
    i, j = saving[1]
    
    res = there_is_a_possible_merge(i,j)
    
    if res != -1:
        
        id1, id2 = res
        direction = is_route_merge_valid(id1, id2)
        if direction == 'l' or direction == 'lr':
            merge_two_routes(id1, id2, 'l')

# %%
for route in routes:
    
    
    if route != (-1, -1, -1):
        
        print ('Route:')
        print (route)
        
        for item in route[1:-1]:
            
            if linehaul_vector[item] != 0:
                print('L')
                
            if backhaul_vector[item] != 0:
                print('B')
# Out:
# Route:
# (0, 20, 22, 1, 0)
# L
# L
# B
# Route:
# (0, 8, 15, 2, 0)
# L
# L
# B
# Route:
# (0, 13, 25, 10, 12, 3, 0)
# L
# L
# L
# L
# B
# Route:
# (0, 21, 14, 4, 0)
# L
# L
# B
# Route:
# (0, 17, 9, 24, 5, 0)
# L
# L
# L
# B
# Route:
# (0, 7, 16, 11, 0)
# L
# L
# L
# Route:
# (0, 18, 0)
# L
# Route:
# (0, 6, 19, 23, 0)
# L
# L
# L

# %%
for route in routes:
    if route == (-1,-1,-1):
        continue
    total_l = 0
    total_b = 0
    for el in route:
        if el == 0:
            continue
        
        total_l += linehaul_vector[el]
        total_b += backhaul_vector[el]
    print(route)
    print(total_l)
    print(total_b)
# Out:
# (0, 20, 22, 1, 0)
# 1196
# 549
# (0, 8, 15, 2, 0)
# 1437
# 558
# (0, 13, 25, 10, 12, 3, 0)
# 1550
# 851
# (0, 21, 14, 4, 0)
# 1161
# 388
# (0, 17, 9, 24, 5, 0)
# 1488
# 194
# (0, 7, 16, 11, 0)
# 1309
# 0
# (0, 18, 0)
# 691
# 0
# (0, 6, 19, 23, 0)
# 1217
# 0

# %%
ordered_savings
# Out:
# [(9.223372036854776e+18, (0, 0)),
#  (9.223372036854776e+18, (1, 1)),
#  (9.223372036854776e+18, (2, 2)),
#  (9.223372036854776e+18, (3, 3)),
#  (9.223372036854776e+18, (4, 4)),
#  (9.223372036854776e+18, (5, 5)),
#  (9.223372036854776e+18, (6, 6)),
#  (9.223372036854776e+18, (7, 7)),
#  (9.223372036854776e+18, (8, 8)),
#  (9.223372036854776e+18, (9, 9)),
#  (9.223372036854776e+18, (10, 10)),
#  (9.223372036854776e+18, (11, 11)),
#  (9.223372036854776e+18, (12, 12)),
#  (9.223372036854776e+18, (13, 13)),
#  (9.223372036854776e+18, (14, 14)),
#  (9.223372036854776e+18, (15, 15)),
#  (9.223372036854776e+18, (16, 16)),
#  (9.223372036854776e+18, (17, 17)),
#  (9.223372036854776e+18, (18, 18)),
#  (9.223372036854776e+18, (19, 19)),
#  (9.223372036854776e+18, (20, 20)),
#  (9.223372036854776e+18, (21, 21)),
#  (9.223372036854776e+18, (22, 22)),
#  (9.223372036854776e+18, (23, 23)),
#  (9.223372036854776e+18, (24, 24)),
#  (9.223372036854776e+18, (25, 25)),
#  (26876.994911809332, (3, 12)),
#  (26876.994911809332, (12, 3)),
#  (25842.55886713752, (10, 12)),
#  (25842.55886713752, (12, 10)),
#  (25707.57333546077, (19, 23)),
#  (25707.57333546077, (23, 19)),
#  (25639.227282754746, (6, 19)),
#  (25639.227282754746, (19, 6)),
#  (25057.6384306864, (13, 25)),
#  (25057.6384306864, (25, 13)),
#  (24720.33591543431, (3, 10)),
#  (24720.33591543431, (10, 3)),
#  (24453.148454315884, (6, 23)),
#  (24453.148454315884, (23, 6)),
#  (23422.525064897065, (4, 14)),
#  (23422.525064897065, (14, 4)),
#  (23111.261726569413, (3, 25)),
#  (23111.261726569413, (25, 3)),
#  (23014.972765793216, (12, 25)),
#  (23014.972765793216, (25, 12)),
#  (22290.085230347024, (10, 14)),
#  (22290.085230347024, (14, 10)),
#  (22151.38052636211, (4, 16)),
#  (22151.38052636211, (16, 4)),
#  (20832.21001904663, (4, 10)),
#  (20832.21001904663, (10, 4)),
#  (20722.63448605837, (12, 14)),
#  (20722.63448605837, (14, 12)),
#  (20705.474144157444, (10, 25)),
#  (20705.474144157444, (25, 10)),
#  (20281.87972531153, (3, 13)),
#  (20281.87972531153, (13, 3)),
#  (20187.454114859116, (12, 13)),
#  (20187.454114859116, (13, 12)),
#  (19807.400672853815, (3, 14)),
#  (19807.400672853815, (14, 3)),
#  (19378.58081313456, (4, 21)),
#  (19378.58081313456, (21, 4)),
#  (19216.192041041893, (4, 12)),
#  (19216.192041041893, (12, 4)),
#  (18971.83557899932, (20, 22)),
#  (18971.83557899932, (22, 20)),
#  (18918.486601044668, (20, 24)),
#  (18918.486601044668, (24, 20)),
#  (18530.613196989063, (14, 21)),
#  (18530.613196989063, (21, 14)),
#  (18376.673157400754, (9, 20)),
#  (18376.673157400754, (20, 9)),
#  (18151.41943241011, (3, 4)),
#  (18151.41943241011, (4, 3)),
#  (17883.47085452726, (10, 13)),
#  (17883.47085452726, (13, 10)),
#  (17606.784387788714, (14, 16)),
#  (17606.784387788714, (16, 14)),
#  (17204.548662092155, (22, 24)),
#  (17204.548662092155, (24, 22)),
#  (17181.568614858395, (16, 21)),
#  (17181.568614858395, (21, 16)),
#  (17027.98985374109, (9, 24)),
#  (17027.98985374109, (24, 9)),
#  (16522.467714042396, (6, 7)),
#  (16522.467714042396, (7, 6)),
#  (16440.597494541624, (7, 19)),
#  (16440.597494541624, (19, 7)),
#  (16262.14034141136, (10, 21)),
#  (16262.14034141136, (21, 10)),
#  (16058.216331577321, (14, 25)),
#  (16058.216331577321, (25, 14)),
#  (15755.635650471915, (7, 16)),
#  (15755.635650471915, (16, 7)),
#  (15427.962372052043, (7, 18)),
#  (15427.962372052043, (18, 7)),
#  (15303.574112351635, (7, 23)),
#  (15303.574112351635, (23, 7)),
#  (15235.26174929038, (8, 13)),
#  (15235.26174929038, (13, 8)),
#  (15097.976128781207, (9, 22)),
#  (15097.976128781207, (22, 9)),
#  (15017.723462753673, (12, 21)),
#  (15017.723462753673, (21, 12)),
#  (14682.769449547439, (10, 16)),
#  (14682.769449547439, (16, 10)),
#  (14491.896913944403, (13, 15)),
#  (14491.896913944403, (15, 13)),
#  (14420.1371504724, (3, 21)),
#  (14420.1371504724, (21, 3)),
#  (14306.147092724928, (8, 25)),
#  (14306.147092724928, (25, 8)),
#  (14263.441642858596, (4, 25)),
#  (14263.441642858596, (25, 4)),
#  (14146.966834619574, (15, 25)),
#  (14146.966834619574, (25, 15)),
#  (13838.73066066314, (8, 15)),
#  (13838.73066066314, (15, 8)),
#  (13488.750631900019, (4, 7)),
#  (13488.750631900019, (7, 4)),
#  (13380.636320921501, (13, 14)),
#  (13380.636320921501, (14, 13)),
#  (13219.418030516883, (12, 16)),
#  (13219.418030516883, (16, 12)),
#  (13163.174911593604, (6, 18)),
#  (13163.174911593604, (18, 6)),
#  (13113.173344610217, (2, 13)),
#  (13113.173344610217, (13, 2)),
#  (13101.062384518225, (2, 8)),
#  (13101.062384518225, (8, 2)),
#  (12772.437109241877, (18, 19)),
#  (12772.437109241877, (19, 18)),
#  (12568.077092664322, (3, 15)),
#  (12568.077092664322, (15, 3)),
#  (12479.427936978991, (3, 16)),
#  (12479.427936978991, (16, 3)),
#  (12444.398112914734, (16, 18)),
#  (12444.398112914734, (18, 16)),
#  (12356.067850228745, (12, 15)),
#  (12356.067850228745, (15, 12)),
#  (12352.973089873167, (18, 23)),
#  (12352.973089873167, (23, 18)),
#  (12255.183331345868, (2, 15)),
#  (12255.183331345868, (15, 2)),
#  (12231.755495965483, (3, 8)),
#  (12231.755495965483, (8, 3)),
#  (12147.06861250245, (2, 25)),
#  (12147.06861250245, (25, 2)),
#  (11999.060789139867, (8, 12)),
#  (11999.060789139867, (12, 8)),
#  (11540.452830475417, (4, 13)),
#  (11540.452830475417, (13, 4)),
#  (11492.483940304985, (1, 22)),
#  (11492.483940304985, (22, 1)),
#  (11440.305226018903, (21, 25)),
#  (11440.305226018903, (25, 21)),
#  (11347.007955737392, (10, 15)),
#  (11347.007955737392, (15, 10)),
#  (11254.12060202194, (16, 19)),
#  (11254.12060202194, (19, 16)),
#  (11252.330374554353, (6, 16)),
#  (11252.330374554353, (16, 6)),
#  (10854.430595586635, (8, 10)),
#  (10854.430595586635, (10, 8)),
#  (10757.823797918118, (3, 11)),
#  (10757.823797918118, (11, 3)),
#  (10753.77683921605, (11, 12)),
#  (10753.77683921605, (12, 11)),
#  (10702.783265387883, (7, 21)),
#  (10702.783265387883, (21, 7)),
#  (10697.026139895224, (13, 17)),
#  (10697.026139895224, (17, 13)),
#  (10646.824534248653, (17, 20)),
#  (10646.824534248653, (20, 17)),
#  (10621.18172428349, (10, 11)),
#  (10621.18172428349, (11, 10)),
#  (10515.464126825811, (4, 18)),
#  (10515.464126825811, (18, 4)),
#  (10431.682182872886, (19, 22)),
#  (10431.682182872886, (22, 19)),
#  (10315.739126830216, (2, 3)),
#  (10315.739126830216, (3, 2)),
#  (10293.39443795939, (11, 25)),
#  (10293.39443795939, (25, 11)),
#  (10219.926805438128, (9, 17)),
#  (10219.926805438128, (17, 9)),
#  (10101.674067962767, (2, 12)),
#  (10101.674067962767, (12, 2)),
#  (10064.204748420127, (16, 23)),
#  (10064.204748420127, (23, 16)),
#  (10014.195061539103, (1, 24)),
#  (10014.195061539103, (24, 1)),
#  (9992.128828698516, (7, 14)),
#  (9992.128828698516, (14, 7)),
#  (9851.014660655928, (1, 20)),
#  (9851.014660655928, (20, 1)),
#  (9779.316912413682, (11, 14)),
#  (9779.316912413682, (14, 11)),
#  (9443.744021905426, (8, 17)),
#  (9443.744021905426, (17, 8)),
#  (9379.102835782041, (11, 13)),
#  (9379.102835782041, (13, 11)),
#  (9375.921622187794, (2, 17)),
#  (9375.921622187794, (17, 2)),
#  (9256.642453920773, (16, 25)),
#  (9256.642453920773, (25, 16)),
#  (9211.531918396378, (13, 21)),
#  (9211.531918396378, (21, 13)),
#  (9114.955437148654, (2, 10)),
#  (9114.955437148654, (10, 2)),
#  (9054.179023060005, (17, 24)),
#  (9054.179023060005, (24, 17)),
#  (9032.68364806682, (22, 23)),
#  (9032.68364806682, (23, 22)),
#  (9023.562086383461, (14, 15)),
#  (9023.562086383461, (15, 14)),
#  (8988.973665331469, (4, 6)),
#  (8988.973665331469, (6, 4)),
#  (8977.70100607265, (4, 19)),
#  (8977.70100607265, (19, 4)),
#  (8905.041609118736, (18, 21)),
#  (8905.041609118736, (21, 18)),
#  (8893.893273411695, (1, 9)),
#  (8893.893273411695, (9, 1)),
#  (8892.846731240892, (5, 17)),
#  (8892.846731240892, (17, 5)),
#  (8774.127077409623, (4, 11)),
#  (8774.127077409623, (11, 4)),
#  (8734.330332701637, (11, 15)),
#  (8734.330332701637, (15, 11)),
#  (8658.483931341456, (17, 25)),
#  (8658.483931341456, (25, 17)),
#  (8521.293572367478, (11, 21)),
#  (8521.293572367478, (21, 11)),
#  (8422.45239094436, (13, 20)),
#  (8422.45239094436, (20, 13)),
#  (8379.128341007152, (8, 14)),
#  (8379.128341007152, (14, 8)),
#  (8356.807089579892, (15, 17)),
#  (8356.807089579892, (17, 15)),
#  (8199.49585299939, (5, 9)),
#  (8199.49585299939, (9, 5)),
#  (8168.2887710381765, (5, 20)),
#  (8168.2887710381765, (20, 5)),
#  (8146.726451699567, (8, 11)),
#  (8146.726451699567, (11, 8)),
#  (8078.305419963312, (6, 22)),
#  (8078.305419963312, (22, 6)),
#  (8033.44061270529, (14, 18)),
#  (8033.44061270529, (18, 14)),
#  (7899.536099043493, (1, 19)),
#  (7899.536099043493, (19, 1)),
#  (7834.850712419735, (4, 23)),
#  (7834.850712419735, (23, 4)),
#  (7578.67758850678, (7, 10)),
#  (7578.67758850678, (10, 7)),
#  (7517.132635264373, (5, 24)),
#  (7517.132635264373, (24, 5)),
#  (7504.1611518782265, (4, 15)),
#  (7504.1611518782265, (15, 4)),
#  (7383.898823204074, (1, 23)),
#  (7383.898823204074, (23, 1)),
#  (7372.263352601143, (17, 22)),
#  (7372.263352601143, (22, 17)),
#  (7337.589244661142, (2, 11)),
#  (7337.589244661142, (11, 2)),
#  (7253.153513366495, (9, 13)),
#  (7253.153513366495, (13, 9)),
#  (7191.477064500599, (19, 20)),
#  (7191.477064500599, (20, 19)),
#  (6990.827044762862, (2, 14)),
#  (6990.827044762862, (14, 2)),
#  (6986.595385270655, (13, 16)),
#  (6986.595385270655, (16, 13)),
#  (6878.607033827835, (11, 16)),
#  (6878.607033827835, (16, 11)),
#  (6837.693762126373, (4, 8)),
#  (6837.693762126373, (8, 4)),
#  (6829.736688097151, (15, 21)),
#  (6829.736688097151, (21, 15)),
#  (6752.437339189713, (1, 6)),
#  (6752.437339189713, (6, 1)),
#  (6716.203258153673, (19, 24)),
#  (6716.203258153673, (24, 19)),
#  (6694.669634315096, (6, 21)),
#  (6694.669634315096, (21, 6)),
#  (6469.626054270317, (5, 13)),
#  (6469.626054270317, (13, 5)),
#  (6455.101679582756, (7, 12)),
#  (6455.101679582756, (12, 7)),
#  (6427.183314930138, (3, 17)),
#  (6427.183314930138, (17, 3)),
#  (6354.928273292087, (19, 21)),
#  (6354.928273292087, (21, 19)),
#  (6337.7528904319315, (5, 22)),
#  (6337.7528904319315, (22, 5)),
#  (6281.893763777406, (2, 5)),
#  (6281.893763777406, (5, 2)),
#  (6207.69543216533, (12, 17)),
#  (6207.69543216533, (17, 12)),
#  (6192.558784190902, (8, 20)),
#  (6192.558784190902, (20, 8)),
#  (6165.266895575123, (8, 21)),
#  (6165.266895575123, (21, 8)),
#  (6137.650527989679, (2, 20)),
#  (6137.650527989679, (20, 2)),
#  (6121.464499512738, (5, 8)),
#  (6121.464499512738, (8, 5)),
#  (6058.049459806007, (10, 18)),
#  (6058.049459806007, (18, 10)),
#  (6020.207157455148, (20, 23)),
#  (6020.207157455148, (23, 20)),
#  (5989.669100281022, (3, 7)),
#  (5989.669100281022, (7, 3)),
#  (5951.377380184887, (13, 24)),
#  (5951.377380184887, (24, 13)),
#  (5861.982800783773, (2, 9)),
#  (5861.982800783773, (9, 2)),
#  (5848.549928763539, (6, 14)),
#  (5848.549928763539, (14, 6)),
#  (5843.597600412697, (23, 24)),
#  (5843.597600412697, (24, 23)),
#  (5826.164584112048, (8, 9)),
#  (5826.164584112048, (9, 8)),
#  (5824.071922469317, (21, 23)),
#  (5824.071922469317, (23, 21)),
#  (5600.546826498379, (2, 4)),
#  (5600.546826498379, (4, 2)),
#  (5582.819989911215, (20, 25)),
#  (5582.819989911215, (25, 20)),
#  (5532.766900686231, (14, 19)),
#  (5532.766900686231, (19, 14)),
#  (5435.288588909693, (5, 15)),
#  (5435.288588909693, (15, 5)),
#  (5239.489711804603, (10, 17)),
#  (5239.489711804603, (17, 10)),
#  (5167.112018734748, (6, 20)),
#  (5167.112018734748, (20, 6)),
#  (5154.83483298098, (5, 25)),
#  (5154.83483298098, (25, 5)),
#  (5146.8958103579735, (2, 21)),
#  (5146.8958103579735, (21, 2)),
#  (5145.747959360691, (12, 18)),
#  (5145.747959360691, (18, 12)),
#  (5134.888796541913, (9, 19)),
#  (5134.888796541913, (19, 9)),
#  (5119.3089725601785, (15, 20)),
#  (5119.3089725601785, (20, 15)),
#  (5081.731934542378, (6, 24)),
#  (5081.731934542378, (24, 6)),
#  (4976.717553092716, (9, 25)),
#  (4976.717553092716, (25, 9)),
#  (4954.429470853767, (14, 23)),
#  (4954.429470853767, (23, 14)),
#  (4944.407755471133, (15, 16)),
#  (4944.407755471133, (16, 15)),
#  (4870.6368868283735, (2, 24)),
#  (4870.6368868283735, (24, 2)),
#  (4866.429209205406, (9, 15)),
#  (4866.429209205406, (15, 9)),
#  (4793.432410944748, (3, 18)),
#  (4793.432410944748, (18, 3)),
#  (4784.6358080767495, (8, 24)),
#  (4784.6358080767495, (24, 8)),
#  (4449.307686160446, (9, 23)),
#  (4449.307686160446, (23, 9)),
#  (4360.3471505610105, (1, 5)),
#  (4360.3471505610105, (5, 1)),
#  (4360.334029311423, (1, 17)),
#  (4360.334029311423, (17, 1)),
#  (4307.78486293417, (8, 16)),
#  (4307.78486293417, (16, 8)),
#  (4286.727889498698, (11, 17)),
#  (4286.727889498698, (17, 11)),
#  (4180.050456135734, (13, 22)),
#  (4180.050456135734, (22, 13)),
#  (3912.251618127935, (15, 24)),
#  (3912.251618127935, (24, 15)),
#  (3857.553930083657, (24, 25)),
#  (3857.553930083657, (25, 24)),
#  (3786.9863536395533, (6, 10)),
#  (3786.9863536395533, (10, 6)),
#  (3780.363339977459, (6, 9)),
#  (3780.363339977459, (9, 6)),
#  (3756.8251790223476, (7, 25)),
#  (3756.8251790223476, (25, 7)),
#  (3701.1430652967556, (3, 5)),
#  (3701.1430652967556, (5, 3)),
#  (3599.6897140848905, (7, 11)),
#  (3599.6897140848905, (11, 7)),
#  (3540.52152014469, (5, 12)),
#  (3540.52152014469, (12, 5)),
#  (3477.8545247496713, (2, 22)),
#  (3477.8545247496713, (22, 2)),
#  (3470.2943223845596, (2, 16)),
#  (3470.2943223845596, (16, 2)),
#  (3423.1097061223045, (14, 17)),
#  (3423.1097061223045, (17, 14)),
#  (3400.6495745936354, (1, 7)),
#  (3400.6495745936354, (7, 1)),
#  (3399.4899327020903, (10, 19)),
#  (3399.4899327020903, (19, 10)),
#  (3341.001469754641, (8, 22)),
#  (3341.001469754641, (22, 8)),
#  (3330.6664656195135, (7, 22)),
#  (3330.6664656195135, (22, 7)),
#  (3178.7798446269153, (3, 20)),
#  (3178.7798446269153, (20, 3)),
#  (3158.3722629550903, (11, 18)),
#  (3158.3722629550903, (18, 11)),
#  (3122.6026975271125, (1, 18)),
#  (3122.6026975271125, (18, 1)),
#  (3050.377564339855, (10, 23)),
#  (3050.377564339855, (23, 10)),
#  (2986.7557075320983, (18, 25)),
#  (2986.7557075320983, (25, 18)),
#  (2965.3140462739902, (12, 20)),
#  (2965.3140462739902, (20, 12)),
#  (2946.692510095505, (3, 9)),
#  (2946.692510095505, (9, 3)),
#  (2924.178653571067, (5, 10)),
#  (2924.178653571067, (10, 5)),
#  (2901.4257458230713, (6, 12)),
#  (2901.4257458230713, (12, 6)),
#  (2901.0533055809537, (18, 22)),
#  (2901.0533055809537, (22, 18)),
#  (2754.4070283894907, (9, 12)),
#  (2754.4070283894907, (12, 9)),
#  (2751.562707044978, (5, 11)),
#  (2751.562707044978, (11, 5)),
#  (2598.718175140524, (15, 22)),
#  (2598.718175140524, (22, 15)),
#  (2581.485928933311, (3, 6)),
#  (2581.485928933311, (6, 3)),
#  (2499.589369734069, (12, 19)),
#  (2499.589369734069, (19, 12)),
#  (2363.562173082497, (22, 25)),
#  (2363.562173082497, (25, 22)),
#  (2304.8869294480683, (4, 17)),
#  (2304.8869294480683, (17, 4)),
#  (2276.53324526659, (7, 13)),
#  (2276.53324526659, (13, 7)),
#  (2254.2030583666856, (12, 23)),
#  (2254.2030583666856, (23, 12)),
#  (2179.479054827818, (3, 19)),
#  (2179.479054827818, (19, 3)),
#  (2146.494062061278, (17, 21)),
#  (2146.494062061278, (21, 17)),
#  (2099.7346270355665, (10, 20)),
#  (2099.7346270355665, (20, 10)),
#  (2064.5317444033535, (3, 24)),
#  (2064.5317444033535, (24, 3)),
#  (2008.3840401269154, (9, 10)),
#  (2008.3840401269154, (10, 9)),
#  (1978.9003627424208, (3, 23)),
#  (1978.9003627424208, (23, 3)),
#  (1894.0134531468902, (12, 24)),
#  (1894.0134531468902, (24, 12)),
#  (1789.0713611306219, (5, 14)),
#  (1789.0713611306219, (14, 5)),
#  (1779.8139459898593, (9, 11)),
#  (1779.8139459898593, (11, 9)),
#  (1779.0474168877736, (13, 18)),
#  (1779.0474168877736, (18, 13)),
#  (1763.5800991991546, (1, 2)),
#  (1763.5800991991546, (2, 1)),
#  (1755.821632505942, (7, 15)),
#  (1755.821632505942, (15, 7)),
#  (1747.1670698973285, (11, 20)),
#  (1747.1670698973285, (20, 11)),
#  (1710.9657824781425, (1, 13)),
#  (1710.9657824781425, (13, 1)),
#  (1661.850570314924, (7, 24)),
#  (1661.850570314924, (24, 7)),
#  (1594.1661235127503, (1, 8)),
#  (1594.1661235127503, (8, 1)),
#  (1503.1403365178485, (6, 11)),
#  (1503.1403365178485, (11, 6)),
#  (1488.6071933340154, (18, 24)),
#  (1488.6071933340154, (24, 18)),
#  (1464.229082555059, (15, 18)),
#  (1464.229082555059, (18, 15)),
#  (1448.2324126772655, (7, 20)),
#  (1448.2324126772655, (20, 7)),
#  (1330.5998042945757, (7, 8)),
#  (1330.5998042945757, (8, 7)),
#  (1276.602589876653, (10, 24)),
#  (1276.602589876653, (24, 10)),
#  (1272.8212306039204, (18, 20)),
#  (1272.8212306039204, (20, 18)),
#  (1256.6165993584073, (5, 19)),
#  (1256.6165993584073, (19, 5)),
#  (1230.7264829968572, (11, 24)),
#  (1230.7264829968572, (24, 11)),
#  (1193.542693495856, (11, 19)),
#  (1193.542693495856, (19, 11)),
#  (1174.6500429276748, (1, 15)),
#  (1174.6500429276748, (15, 1)),
#  (1162.5371792001315, (11, 23)),
#  (1162.5371792001315, (23, 11)),
#  (1156.4242917053743, (1, 16)),
#  (1156.4242917053743, (16, 1)),
#  (1115.131060354639, (5, 23)),
#  (1115.131060354639, (23, 5)),
#  (1095.4044950412863, (8, 18)),
#  (1095.4044950412863, (18, 8)),
#  (1081.3486359426606, (6, 25)),
#  (1081.3486359426606, (25, 6)),
#  (1063.5390824505412, (4, 5)),
#  (1063.5390824505412, (5, 4)),
#  (1055.4474031844366, (5, 21)),
#  (1055.4474031844366, (21, 5)),
#  (986.9901003845516, (16, 17)),
#  (986.9901003845516, (17, 16)),
#  (986.1382780981075, (17, 19)),
#  (986.1382780981075, (19, 17)),
#  (985.507627194711, (7, 9)),
#  (985.507627194711, (9, 7)),
#  (969.2364876116153, (2, 7)),
#  (969.2364876116153, (7, 2)),
#  (955.9489424516032, (3, 22)),
#  (955.9489424516032, (22, 3)),
#  (898.503493018934, (9, 18)),
#  (898.503493018934, (18, 9)),
#  (845.347265599914, (5, 6)),
#  (845.347265599914, (6, 5)),
#  (834.5962130527623, (17, 23)),
#  (834.5962130527623, (23, 17)),
#  (832.8043598115219, (9, 14)),
#  (832.8043598115219, (14, 9)),
#  (827.264383133981, (12, 22)),
#  (827.264383133981, (22, 12)),
#  (822.191315950502, (1, 25)),
#  (822.191315950502, (25, 1)),
#  (801.2838272563276, (2, 18)),
#  (801.2838272563276, (18, 2)),
#  (783.865848712685, (14, 20)),
#  (783.865848712685, (20, 14)),
#  (779.4310549362563, (16, 22)),
#  (779.4310549362563, (22, 16)),
#  (744.5382233490709, (19, 25)),
#  (744.5382233490709, (25, 19)),
#  (701.7421680151456, (23, 25)),
#  (701.7421680151456, (25, 23)),
#  (566.3873439225208, (6, 17)),
#  (566.3873439225208, (17, 6)),
#  (542.5821296737649, (11, 22)),
#  (542.5821296737649, (22, 11)),
#  (424.69022371735264, (10, 22)),
#  (424.69022371735264, (22, 10)),
#  (416.79498876845173, (1, 4)),
#  (416.79498876845173, (4, 1)),
#  (384.9720922554552, (14, 24)),
#  (384.9720922554552, (24, 14)),
#  (351.28184832199986, (5, 16)),
#  (351.28184832199986, (16, 5)),
#  (304.7544981897008, (6, 13)),
#  (304.7544981897008, (13, 6)),
#  (288.24769623055, (1, 21)),
#  (288.24769623055, (21, 1)),
#  (278.1142506591568, (6, 15)),
#  (278.1142506591568, (15, 6)),
#  (273.88946930720704, (9, 21)),
#  (273.88946930720704, (21, 9)),
#  (249.70500757485206, (4, 9)),
#  (249.70500757485206, (9, 4)),
#  (207.90396457690804, (20, 21)),
#  (207.90396457690804, (21, 20)),
#  (200.72683276596217, (1, 3)),
#  (200.72683276596217, (3, 1)),
#  (182.5106124989543, (4, 20)),
#  (182.5106124989543, (20, 4)),
#  (149.74855962452057, (1, 12)),
#  (149.74855962452057, (12, 1)),
#  (129.46777072807527, (15, 23)),
#  (129.46777072807527, (23, 15)),
#  (127.2767160992571, (1, 11)),
#  (127.2767160992571, (11, 1)),
#  (123.28379582875277, (16, 24)),
#  (123.28379582875277, (24, 16)),
#  (121.38602696897578, (4, 22)),
#  (121.38602696897578, (22, 4)),
#  (119.38054802777333, (13, 23)),
#  (119.38054802777333, (23, 13)),
#  (118.8983253727638, (15, 19)),
#  (118.8983253727638, (19, 15)),
#  (109.7937735837113, (13, 19)),
#  (109.7937735837113, (19, 13)),
#  (109.76543928781393, (6, 8)),
#  (109.76543928781393, (8, 6)),
#  (62.75462215991138, (1, 14)),
#  (62.75462215991138, (14, 1)),
#  (58.978087423663965, (21, 24)),
#  (58.978087423663965, (24, 21)),
#  (56.567069515105686, (21, 22)),
#  (56.567069515105686, (22, 21)),
#  (39.67970749020242, (5, 18)),
#  (39.67970749020242, (18, 5)),
#  (35.90296257018417, (4, 24)),
#  (35.90296257018417, (24, 4)),
#  (35.49598018164397, (2, 6)),
#  (35.49598018164397, (6, 2)),
#  (33.66366188057873, (5, 7)),
#  (33.66366188057873, (7, 5)),
#  (31.59274083701166, (1, 10)),
#  (31.59274083701166, (10, 1)),
#  (31.321516225834785, (16, 20)),
#  (31.321516225834785, (20, 16)),
#  (25.92465331745916, (8, 23)),
#  (25.92465331745916, (23, 8)),
#  (18.231835870901705, (8, 19)),
#  (18.231835870901705, (19, 8)),
#  (15.486740551576077, (14, 22)),
#  (15.486740551576077, (22, 14)),
#  (8.983762237770861, (7, 17)),
#  (8.983762237770861, (17, 7)),
#  (3.642403225763701, (17, 18)),
#  (3.642403225763701, (18, 17)),
#  (2.400630235533754, (9, 16)),
#  (2.400630235533754, (16, 9)),
#  (0.6695182295261475, (2, 23)),
#  (0.6695182295261475, (23, 2)),
#  (0.03656256294925697, (2, 19)),
#  (0.03656256294925697, (19, 2)),
#  (0.0, (0, 1)),
#  (0.0, (0, 2)),
#  (0.0, (0, 3)),
#  (0.0, (0, 4)),
#  (0.0, (0, 5)),
#  (0.0, (0, 6)),
#  (0.0, (0, 7)),
#  (0.0, (0, 8)),
#  (0.0, (0, 9)),
#  (0.0, (0, 10)),
#  (0.0, (0, 11)),
#  (0.0, (0, 12)),
#  (0.0, (0, 13)),
#  (0.0, (0, 14)),
#  (0.0, (0, 15)),
#  (0.0, (0, 16)),
#  (0.0, (0, 17)),
#  (0.0, (0, 18)),
#  (0.0, (0, 19)),
#  (0.0, (0, 20)),
#  (0.0, (0, 21)),
#  (0.0, (0, 22)),
#  (0.0, (0, 23)),
#  (0.0, (0, 24)),
#  (0.0, (0, 25)),
#  (0.0, (1, 0)),
#  (0.0, (2, 0)),
#  (0.0, (3, 0)),
#  (0.0, (4, 0)),
#  (0.0, (5, 0)),
#  (0.0, (6, 0)),
#  (0.0, (7, 0)),
#  (0.0, (8, 0)),
#  (0.0, (9, 0)),
#  (0.0, (10, 0)),
#  (0.0, (11, 0)),
#  (0.0, (12, 0)),
#  (0.0, (13, 0)),
#  (0.0, (14, 0)),
#  (0.0, (15, 0)),
#  (0.0, (16, 0)),
#  (0.0, (17, 0)),
#  (0.0, (18, 0)),
#  (0.0, (19, 0)),
#  (0.0, (20, 0)),
#  (0.0, (21, 0)),
#  (0.0, (22, 0)),
#  (0.0, (23, 0)),
#  (0.0, (24, 0)),
#  (0.0, (25, 0))]
