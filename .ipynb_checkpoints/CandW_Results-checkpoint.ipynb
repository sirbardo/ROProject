# %%
import os
from tabulate import tabulate

# %%
def get_table(path):
    table = []
    files = os.listdir(path)
    files.sort()
    for filename in files:
        with open(path+filename,'r') as f:
            content = f.read()
        content = content.split('\n')
        of = float(content[0].split(' ')[2])
        time = float(content[1].split(' ')[3])+float(content[4].split(' ')[4])

        with open('Instances/'+filename,'r') as f:
            content = f.read()
        content = content.split('\n')
        n_of_customers = int(content[0])

        with open('DetailedSols/RPA_Solutions/Detailed_Solution_'+filename,'r') as f:
            content = f.read()
        content = content.split('\n')
        opt_val = float(content[8].split(' ')[3])
        gap = of - opt_val

        table.append([filename[0:2],n_of_customers,of,time,gap])
    
    return table

# %%
table1 = get_table('parallel_routes/')
print(tabulate(table1,headers=['instance name','customers','objective value','time','cost gap'],tablefmt='grid',stralign='right',numalign='decimal'))
# Out:
# +-----------------+-------------+-------------------+------------+---------------+
# |   instance name |   customers |   objective value |       time |      cost gap |
# +=================+=============+===================+============+===============+
# |              A1 |          25 |            230915 |  0.0555546 |   1028.95     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              A2 |          25 |            187985 |  0.0526097 |   7866.32     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              A3 |          25 |            155796 |  0.0600808 |  -7608.59     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              A4 |          25 |            155796 |  0.0575838 |      0.408808 |
# +-----------------+-------------+-------------------+------------+---------------+
# |              B1 |          30 |            253735 |  0.0943601 |  14654.5      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              B2 |          30 |            211863 |  0.119575  |  13815        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              B3 |          30 |            196773 |  0.146057  |  27401.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C1 |          40 |            267740 |  0.310164  |  17183.7      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C2 |          40 |            228651 |  0.351897  |  13631        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C3 |          40 |            214949 |  0.400154  |  15602.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C4 |          40 |            214949 |  0.333802  |  19582.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D1 |          38 |            336030 |  0.194318  |  13500.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D2 |          38 |            336030 |  0.219239  |  19322.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D3 |          38 |            268535 |  0.183822  |  29055.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D4 |          38 |            220873 |  0.30068   |  15041.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              E1 |          45 |            244207 |  0.413876  |   5326.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              E2 |          45 |            234003 |  0.485138  |  21739.9      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              E3 |          45 |            234003 |  0.49931   |  27343.9      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F1 |          60 |            280442 |  1.6451    |  17268.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F2 |          60 |            280442 |  1.51922   |  15228.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F3 |          60 |            259441 |  1.69504   |  18320.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F4 |          60 |            259441 |  1.7684    |  25579.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G1 |          57 |            310006 |  0.846446  |   3700.13     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G2 |          57 |            246063 |  0.874139  |    622.488    |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G3 |          57 |            240011 |  1.12113   |  10503.7      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G4 |          57 |            240011 |  1.13451   |   7489.67     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G5 |          57 |            228727 |  1.41324   |   6997.45     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G6 |          57 |            220102 |  1.26147   |   6645.44     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H1 |          68 |            317854 |  1.83853   |  48921.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H2 |          68 |            316953 |  1.82382   |  63588.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H3 |          68 |            316953 |  1.93817   |  69504.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H4 |          68 |            316953 |  1.9135    |  66732.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H5 |          68 |            316953 |  1.82752   |  70832.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H6 |          68 |            316953 |  1.85868   |  67818.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I1 |          90 |            367960 |  5.26658   |  17713.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I2 |          90 |            349565 |  5.305     |  39621.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I3 |          90 |            348293 |  5.96798   |  53786.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I4 |          90 |            348293 |  5.59084   |  52305.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I5 |          90 |            348293 |  5.60386   |  47057.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J1 |          94 |            368847 |  6.17422   |  33840.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J2 |          94 |            349403 |  6.70538   |  38985.9      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J3 |          94 |            318985 |  8.19853   |  39765.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J4 |          94 |            329386 |  7.78421   |  32852.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K1 |         113 |            441293 | 15.1821    |  47221.7      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K2 |         113 |            448120 | 13.791     |  85990.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K3 |         113 |            448120 | 13.9538    |  82426.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K4 |         113 |            437779 | 13.7912    |  88829.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L1 |         150 |            500588 | 37.6495    |  82691.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L2 |         150 |            500588 | 38.3463    |  99359.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L3 |         150 |            500588 | 36.7316    |  97909.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L4 |         150 |            500588 | 37.1111    | 115952        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L5 |         150 |            500588 | 36.2596    | 113023        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M1 |         125 |            451109 | 18.7359    |  52515.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M2 |         125 |            451109 | 18.3053    |  54191.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M3 |         125 |            454186 | 18.62      |  78490        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M4 |         125 |            447824 | 18.2919    |  99684.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N1 |         150 |            457885 | 37.2903    |  49783.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N2 |         150 |            457885 | 37.7324    |  49818.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N3 |         150 |            452203 | 38.2986    |  57864.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N4 |         150 |            452203 | 38.7481    |  57414.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N5 |         150 |            451729 | 39.4028    |  78252.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N6 |         150 |            451729 | 37.785     |  77969.6      |
# +-----------------+-------------+-------------------+------------+---------------+

# %%
table2 = get_table('sequential_routes/')
print(tabulate(table2,headers=['instance name','customers','objective value','time','cost gap'],tablefmt='grid',stralign='right',numalign='decimal'))
# Out:
# +-----------------+-------------+-------------------+-----------+------------+
# |   instance name |   customers |   objective value |      time |   cost gap |
# +=================+=============+===================+===========+============+
# |              B3 |          30 |            200553 |  0.147721 |    31180.6 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              C4 |          40 |            222236 |  0.213923 |    26870.4 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              D2 |          38 |            343087 |  0.116166 |    26379.3 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              D4 |          38 |            257180 |  0.209683 |    51348.3 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              E1 |          45 |            273237 |  0.230122 |    34357.1 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              E2 |          45 |            241505 |  0.617716 |    29241.8 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              G3 |          57 |            289358 |  0.791917 |    59851   |
# +-----------------+-------------+-------------------+-----------+------------+
# |              H1 |          68 |            322757 |  1.05617  |    53823.9 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              H3 |          68 |            299725 |  2.84236  |    52275.9 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              I3 |          90 |            385540 |  4.66843  |    91033.3 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              K1 |         113 |            491114 |  7.65874  |    97043.4 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              L1 |         150 |            602430 | 12.6872   |   184534   |
# +-----------------+-------------+-------------------+-----------+------------+
# |              L2 |         150 |            523839 | 20.7517   |   122611   |
# +-----------------+-------------+-------------------+-----------+------------+
# |              M1 |         125 |            471400 |  9.41731  |    72806.6 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              M3 |         125 |            471834 |  8.65612  |    96138.3 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              M4 |         125 |            407519 | 14.9102   |    59378.6 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              N2 |         150 |            492194 | 30.6754   |    84128.4 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              N4 |         150 |            487170 | 25.6317   |    92382.3 |
# +-----------------+-------------+-------------------+-----------+------------+
# |              N6 |         150 |            459351 | 30.0846   |    85592   |
# +-----------------+-------------+-------------------+-----------+------------+
