# %% [markdown]
# #RO Project#
#
# 1. Read instances' data from file
# 2. Initialize the parameters read from file
# 3. n = number of customers
# 4. c = matrix of costs
# 5. ml = max load of the vehicle
# 6. l = linehaul values vector
# 7. b = backhaul values vector
# 8. Initialize the matrix s of savings
# 9. for i = 1:n
#     1. for j = 1:n
#         1. If i == j
#             1. s_ij = +inf
#         2. else
#             1. s_ij = c_i0 + c_0j - c_ij
# 10. Routes = list of empty routes
# 11. for i = 1:n
#     1. Routes_i = (0,i,0)
# 12. Order the savings s in a non increasing fashion
# 13. for each route in Routes:
#     1. while this route can be feasibly (respecting the constraints) merged further:
# 	   1.determine the first saving s_ki or s_jl in the ordered list that can feasibly be used to merge the current route with another route containing either the arc (k, 0) or (0, l).
#        	   2. merge the two routes.

# %%
import numpy as np
import sys

# %%
filename = 'Instances/A1.txt'
with open(filename, 'r') as f:
    content = f.read()
    print(content)
# Out:
# 25
# 1
# 8
# 12000   16000   0   1550
# 9795   21510   0   549   0
# 7758   10895   0   558   0
# 12927   2464   0   851   0
# 23286   5538   0   388   0
# 7416   15826   0   194   0
# 21524   24879   483   0   0
# 22337   17915   389   0   0
# 7642   9722   435   0   0
# 3707   20036   452   0   0
# 15492   2721   343   0   0
# 12430   10638   444   0   0
# 13595   1918   350   0   0
# 4290   2721   307   0   0
# 18684   5268   810   0   0
# 8686   9546   1002   0   0
# 23140   10989   476   0   0
# 5263   14289   674   0   0
# 19557   17564   691   0   0
# 23281   29684   675   0   0
# 374   22683   410   0   0
# 18804   9082   351   0   0
# 5444   25004   786   0   0
# 20390   25745   59   0   0
# 4310   21692   362   0   0
# 8526   2495   550   0   0

# %%
content = content.split('\n')[0:-1] #-1 because the last element is a newline, so we skip it

# %%
n_of_customers = int(content[0])
n_of_vehicles = int(content[2])
capacity = int(content[3].split()[3])
linehaul_vector = [0] + [int(i.split()[2]) for i in content[4:]] #linehaul data is in the fourth column
backhaul_vector = [0] + [int(i.split()[3]) for i in content[4:]] #and backhaul is in the third

# %%
import math

def euclidean_distance2D(point1, point2):
    
    x1, y1 = point1
    x2, y2 = point2
    
    return (math.sqrt((x1-x2)**2 + (y1-y2)**2))

# %%
cost_matrix = []

x_coords = [int(i.split()[0]) for i in content[3:]]
y_coords = [int(i.split()[1]) for i in content[3:]]

for i, (x1, y1) in enumerate(zip(x_coords, y_coords)): #could also enumerate over y_coords, the dimensions are equal
    
    current_row = []
    
    for j, (x2, y2) in enumerate(zip(x_coords, y_coords)):
        
        current_row += [euclidean_distance2D((x1,y1), (x2,y2))]
        
    cost_matrix += [current_row]

# %%
cost_matrix = np.array(cost_matrix)
savings_matrix = np.zeros((n_of_customers, n_of_customers))

# %%
for i in range(n_of_customers):
    for j in range(n_of_customers):
        if (i==j):
            savings_matrix[i][j] = sys.maxsize
        else:
            savings_matrix[i][j] = cost_matrix[i][0] + cost_matrix[0][j] - cost_matrix[i][j]

# %%
routes = []

# %%
for i in range(n_of_customers):
    
    routes += [(0, i+1, 0)]

# %%
cost_matrix.shape
# Out:
# (26, 26)

# %%
ordered_savings = []

for (i, j), el in np.ndenumerate(savings_matrix):
    ordered_savings += [(el, (i+1, j+1))]

ordered_savings.sort(key=lambda x: x[0], reverse=True)
ordered_i_savings = list(ordered_savings)
ordered_j_savings = list(ordered_savings)
ordered_i_savings.sort(key=lambda x: (x[1][0], -x[0]))
ordered_j_savings.sort(key=lambda x: (x[1][1], -x[0]))

# %%
def is_route_merge_valid(id_route1, id_route2):
    
    """First, try if you can merge it with the end of route1 to end of route2"""
        
    possible_route = list( routes[id_route1][:-1] + routes[id_route2][1:]) #the merge itself is just skipping the left and right
    
    i = 0
    
    
    cost_of_possible_route_backhaul = 0
    cost_of_possible_route_linehaul = 0
    is_right_possible = True
    
    for node_touched in possible_route[1:-1]:
        
        if linehaul_vector[node_touched] == 0:#linehaul_vector is 0 if a node is not a linehaul node, so we have to go to the next for
            break
        else:
            cost_of_possible_route_linehaul += linehaul_vector[node_touched]
            i+=1
            
    starting_point = i
    if i < len(possible_route[1:-1]):
        for node_touched in possible_route[starting_point+1:-1]:
            
            if backhaul_vector[node_touched] == 0 and i != len(possible_route): #we are trying to linehaul AFTER we started backhauling... constraint broken:
                is_right_possible = False
                #print(i, backhaul_vector[node_touched], node_touched)
            else:
                cost_of_possible_route_backhaul += backhaul_vector[node_touched]
                i+=1
                
        
    if (cost_of_possible_route_backhaul > capacity or cost_of_possible_route_linehaul > capacity):
        is_right_possible = False
        
    if (cost_of_possible_route_linehaul == 0): # we are only backhauling
        is_right_possible = False

        
    """Now the other possible route."""
        
    possible_route = list( routes[id_route2][:-1] + routes[id_route1][1:]) #the merge itself is just skipping the left and right
    
    i = 0
    
    cost_of_possible_route_backhaul = 0
    cost_of_possible_route_linehaul = 0
    is_left_possible = True
    
    for node_touched in possible_route[1:-1]:
        
        if linehaul_vector[node_touched] == 0:#linehaul_vector is 0 if a node is not a linehaul node, so we have to go to the next for
            break
        else:
            cost_of_possible_route_linehaul += linehaul_vector[node_touched]
            i+=1
            
    starting_point = i
    if i < len(possible_route[1:-1]):
        for node_touched in possible_route[starting_point+1:-1]:
            
            if backhaul_vector[node_touched] == 0 and i != len(possible_route): #we are trying to linehaul AFTER we started backhauling... constraint broken:
                is_left_possible = False
            else:
                cost_of_possible_route_backhaul += backhaul_vector[node_touched]
                i+=1
                
        
    if (cost_of_possible_route_backhaul > capacity or cost_of_possible_route_linehaul > capacity):
        is_left_possible = False
        
    if (cost_of_possible_route_linehaul == 0): # we are only backhauling
        is_left_possible = False

        
    #print(is_left_possible, is_right_possible)
        
    if not is_left_possible and not is_right_possible:
        return ('')
    elif is_left_possible and is_right_possible:
        return ('lr')
    elif is_left_possible:
        return 'l'
    else:
        return 'r'

# %%
def merge_two_routes(id_route, found_id, direction_of_merge):

    if id_route== found_id:
        return
    
    tmp_list1 = list(routes[id_route])
    tmp_list2 = list(routes[found_id])
        
    tmp_list1.pop(0)
    tmp_list1.pop(-1)
    tmp_list2.pop(0)
    tmp_list2.pop(-1)
    
    if direction_of_merge == 'l':
        
        routes[id_route] = tuple([0]+tmp_list2+tmp_list1+[0])
    
    if direction_of_merge == 'r':
        
        routes[id_route] = tuple([0]+tmp_list1+tmp_list2+[0])
    
    routes[found_id] = (-1,-1,-1)

# %%
direction_of_merge = is_route_merge_valid(10, 18)
print(direction_of_merge)
# Out:
# lr

# %%
def there_is_a_possible_merge(i, j):
    
    
    for id1, route1 in enumerate(routes):
        
        for id2, route2 in enumerate(routes):
            
            if route1 == (-1, -1, -1) or route2 == (-1, -1, -1):
                continue
                
            if (id1 != id2):
                
                if (route1[1] == j and route2[-2] == i):
                    
                    return (id1, id2)
    
    return -1

# %%
for idx, saving in enumerate(ordered_savings[25:]): # '25:' because we are not interested in the infinite savings, since their i,j pairs won't allow feasible merges
    
    
    i, j = saving[1]
    
    res = there_is_a_possible_merge(i,j)
    
    if res != -1:
        
        id1, id2 = res
        direction = is_route_merge_valid(id1, id2)
        if direction == 'l' or direction == 'lr':
            merge_two_routes(id1, id2, 'l')

# %%
for route in routes:
    
    
    if route != (-1, -1, -1):
        
        print ('Route:')
        print (route)
        
        for item in route[1:-1]:
            
            if linehaul_vector[item] != 0:
                print('L')
                
            if backhaul_vector[item] != 0:
                print('B')
# Out:
# Route:
# (0, 10, 25, 21, 23, 2, 1, 0)
# L
# L
# L
# L
# B
# B
# Route:
# (0, 9, 14, 3, 0)
# L
# L
# B
# Route:
# (0, 16, 11, 13, 4, 0)
# L
# L
# L
# B
# Route:
# (0, 12, 15, 5, 0)
# L
# L
# B
# Route:
# (0, 6, 18, 0)
# L
# L
# Route:
# (0, 8, 19, 0)
# L
# L
# Route:
# (0, 17, 22, 0)
# L
# L
# Route:
# (0, 7, 20, 24, 0)
# L
# L
# L

# %%
for route in routes:
    if route == (-1,-1,-1):
        continue
    total_l = 0
    total_b = 0
    for el in route:
        if el == 0:
            continue
        
        total_l += linehaul_vector[el]
        total_b += backhaul_vector[el]
    print(route)
    print(total_l)
    print(total_b)
# Out:
# (0, 10, 25, 21, 23, 2, 1, 0)
# 1303
# 1107
# (0, 9, 14, 3, 0)
# 1262
# 851
# (0, 16, 11, 13, 4, 0)
# 1227
# 388
# (0, 12, 15, 5, 0)
# 1352
# 194
# (0, 6, 18, 0)
# 1174
# 0
# (0, 8, 19, 0)
# 1110
# 0
# (0, 17, 22, 0)
# 1460
# 0
# (0, 7, 20, 24, 0)
# 1161
# 0

# %%
ordered_savings
# Out:
# [(9.223372036854776e+18, (1, 1)),
#  (9.223372036854776e+18, (2, 2)),
#  (9.223372036854776e+18, (3, 3)),
#  (9.223372036854776e+18, (4, 4)),
#  (9.223372036854776e+18, (5, 5)),
#  (9.223372036854776e+18, (6, 6)),
#  (9.223372036854776e+18, (7, 7)),
#  (9.223372036854776e+18, (8, 8)),
#  (9.223372036854776e+18, (9, 9)),
#  (9.223372036854776e+18, (10, 10)),
#  (9.223372036854776e+18, (11, 11)),
#  (9.223372036854776e+18, (12, 12)),
#  (9.223372036854776e+18, (13, 13)),
#  (9.223372036854776e+18, (14, 14)),
#  (9.223372036854776e+18, (15, 15)),
#  (9.223372036854776e+18, (16, 16)),
#  (9.223372036854776e+18, (17, 17)),
#  (9.223372036854776e+18, (18, 18)),
#  (9.223372036854776e+18, (19, 19)),
#  (9.223372036854776e+18, (20, 20)),
#  (9.223372036854776e+18, (21, 21)),
#  (9.223372036854776e+18, (22, 22)),
#  (9.223372036854776e+18, (23, 23)),
#  (9.223372036854776e+18, (24, 24)),
#  (9.223372036854776e+18, (25, 25)),
#  (26876.994911809332, (4, 13)),
#  (26876.994911809332, (13, 4)),
#  (25842.55886713752, (11, 13)),
#  (25842.55886713752, (13, 11)),
#  (25707.57333546077, (20, 24)),
#  (25707.57333546077, (24, 20)),
#  (25639.227282754746, (7, 20)),
#  (25639.227282754746, (20, 7)),
#  (24720.33591543431, (4, 11)),
#  (24720.33591543431, (11, 4)),
#  (24453.148454315884, (7, 24)),
#  (24453.148454315884, (24, 7)),
#  (23422.525064897065, (5, 15)),
#  (23422.525064897065, (15, 5)),
#  (22290.085230347024, (11, 15)),
#  (22290.085230347024, (15, 11)),
#  (22151.38052636211, (5, 17)),
#  (22151.38052636211, (17, 5)),
#  (20832.21001904663, (5, 11)),
#  (20832.21001904663, (11, 5)),
#  (20722.63448605837, (13, 15)),
#  (20722.63448605837, (15, 13)),
#  (20281.87972531153, (4, 14)),
#  (20281.87972531153, (14, 4)),
#  (20187.454114859116, (13, 14)),
#  (20187.454114859116, (14, 13)),
#  (19807.400672853815, (4, 15)),
#  (19807.400672853815, (15, 4)),
#  (19378.58081313456, (5, 22)),
#  (19378.58081313456, (22, 5)),
#  (19216.192041041893, (5, 13)),
#  (19216.192041041893, (13, 5)),
#  (18971.83557899932, (21, 23)),
#  (18971.83557899932, (23, 21)),
#  (18918.486601044668, (21, 25)),
#  (18918.486601044668, (25, 21)),
#  (18530.613196989063, (15, 22)),
#  (18530.613196989063, (22, 15)),
#  (18376.673157400754, (10, 21)),
#  (18376.673157400754, (21, 10)),
#  (18151.41943241011, (4, 5)),
#  (18151.41943241011, (5, 4)),
#  (17883.47085452726, (11, 14)),
#  (17883.47085452726, (14, 11)),
#  (17606.784387788714, (15, 17)),
#  (17606.784387788714, (17, 15)),
#  (17204.548662092155, (23, 25)),
#  (17204.548662092155, (25, 23)),
#  (17181.568614858395, (17, 22)),
#  (17181.568614858395, (22, 17)),
#  (17027.98985374109, (10, 25)),
#  (17027.98985374109, (25, 10)),
#  (16522.467714042396, (7, 8)),
#  (16522.467714042396, (8, 7)),
#  (16440.597494541624, (8, 20)),
#  (16440.597494541624, (20, 8)),
#  (16262.14034141136, (11, 22)),
#  (16262.14034141136, (22, 11)),
#  (15755.635650471915, (8, 17)),
#  (15755.635650471915, (17, 8)),
#  (15427.962372052043, (8, 19)),
#  (15427.962372052043, (19, 8)),
#  (15303.574112351635, (8, 24)),
#  (15303.574112351635, (24, 8)),
#  (15235.26174929038, (9, 14)),
#  (15235.26174929038, (14, 9)),
#  (15097.976128781207, (10, 23)),
#  (15097.976128781207, (23, 10)),
#  (15017.723462753673, (13, 22)),
#  (15017.723462753673, (22, 13)),
#  (14682.769449547439, (11, 17)),
#  (14682.769449547439, (17, 11)),
#  (14491.896913944403, (14, 16)),
#  (14491.896913944403, (16, 14)),
#  (14420.1371504724, (4, 22)),
#  (14420.1371504724, (22, 4)),
#  (13838.73066066314, (9, 16)),
#  (13838.73066066314, (16, 9)),
#  (13488.750631900019, (5, 8)),
#  (13488.750631900019, (8, 5)),
#  (13380.636320921501, (14, 15)),
#  (13380.636320921501, (15, 14)),
#  (13219.418030516883, (13, 17)),
#  (13219.418030516883, (17, 13)),
#  (13163.174911593604, (7, 19)),
#  (13163.174911593604, (19, 7)),
#  (13113.173344610217, (3, 14)),
#  (13113.173344610217, (14, 3)),
#  (13101.062384518225, (3, 9)),
#  (13101.062384518225, (9, 3)),
#  (12772.437109241877, (19, 20)),
#  (12772.437109241877, (20, 19)),
#  (12568.077092664322, (4, 16)),
#  (12568.077092664322, (16, 4)),
#  (12479.427936978991, (4, 17)),
#  (12479.427936978991, (17, 4)),
#  (12444.398112914734, (17, 19)),
#  (12444.398112914734, (19, 17)),
#  (12356.067850228745, (13, 16)),
#  (12356.067850228745, (16, 13)),
#  (12352.973089873167, (19, 24)),
#  (12352.973089873167, (24, 19)),
#  (12255.183331345868, (3, 16)),
#  (12255.183331345868, (16, 3)),
#  (12231.755495965483, (4, 9)),
#  (12231.755495965483, (9, 4)),
#  (11999.060789139867, (9, 13)),
#  (11999.060789139867, (13, 9)),
#  (11540.452830475417, (5, 14)),
#  (11540.452830475417, (14, 5)),
#  (11492.483940304985, (2, 23)),
#  (11492.483940304985, (23, 2)),
#  (11347.007955737392, (11, 16)),
#  (11347.007955737392, (16, 11)),
#  (11254.12060202194, (17, 20)),
#  (11254.12060202194, (20, 17)),
#  (11252.330374554353, (7, 17)),
#  (11252.330374554353, (17, 7)),
#  (10854.430595586635, (9, 11)),
#  (10854.430595586635, (11, 9)),
#  (10757.823797918118, (4, 12)),
#  (10757.823797918118, (12, 4)),
#  (10753.77683921605, (12, 13)),
#  (10753.77683921605, (13, 12)),
#  (10702.783265387883, (8, 22)),
#  (10702.783265387883, (22, 8)),
#  (10697.026139895224, (14, 18)),
#  (10697.026139895224, (18, 14)),
#  (10646.824534248653, (18, 21)),
#  (10646.824534248653, (21, 18)),
#  (10621.18172428349, (11, 12)),
#  (10621.18172428349, (12, 11)),
#  (10515.464126825811, (5, 19)),
#  (10515.464126825811, (19, 5)),
#  (10431.682182872886, (20, 23)),
#  (10431.682182872886, (23, 20)),
#  (10315.739126830216, (3, 4)),
#  (10315.739126830216, (4, 3)),
#  (10219.926805438128, (10, 18)),
#  (10219.926805438128, (18, 10)),
#  (10101.674067962767, (3, 13)),
#  (10101.674067962767, (13, 3)),
#  (10064.204748420127, (17, 24)),
#  (10064.204748420127, (24, 17)),
#  (10014.195061539103, (2, 25)),
#  (10014.195061539103, (25, 2)),
#  (9992.128828698516, (8, 15)),
#  (9992.128828698516, (15, 8)),
#  (9851.014660655928, (2, 21)),
#  (9851.014660655928, (21, 2)),
#  (9779.316912413682, (12, 15)),
#  (9779.316912413682, (15, 12)),
#  (9443.744021905426, (9, 18)),
#  (9443.744021905426, (18, 9)),
#  (9379.102835782041, (12, 14)),
#  (9379.102835782041, (14, 12)),
#  (9375.921622187794, (3, 18)),
#  (9375.921622187794, (18, 3)),
#  (9211.531918396378, (14, 22)),
#  (9211.531918396378, (22, 14)),
#  (9114.955437148654, (3, 11)),
#  (9114.955437148654, (11, 3)),
#  (9054.179023060005, (18, 25)),
#  (9054.179023060005, (25, 18)),
#  (9032.68364806682, (23, 24)),
#  (9032.68364806682, (24, 23)),
#  (9023.562086383461, (15, 16)),
#  (9023.562086383461, (16, 15)),
#  (8988.973665331469, (5, 7)),
#  (8988.973665331469, (7, 5)),
#  (8977.70100607265, (5, 20)),
#  (8977.70100607265, (20, 5)),
#  (8905.041609118736, (19, 22)),
#  (8905.041609118736, (22, 19)),
#  (8893.893273411695, (2, 10)),
#  (8893.893273411695, (10, 2)),
#  (8892.846731240892, (6, 18)),
#  (8892.846731240892, (18, 6)),
#  (8774.127077409623, (5, 12)),
#  (8774.127077409623, (12, 5)),
#  (8734.330332701637, (12, 16)),
#  (8734.330332701637, (16, 12)),
#  (8521.293572367478, (12, 22)),
#  (8521.293572367478, (22, 12)),
#  (8422.45239094436, (14, 21)),
#  (8422.45239094436, (21, 14)),
#  (8379.128341007152, (9, 15)),
#  (8379.128341007152, (15, 9)),
#  (8356.807089579892, (16, 18)),
#  (8356.807089579892, (18, 16)),
#  (8199.49585299939, (6, 10)),
#  (8199.49585299939, (10, 6)),
#  (8168.2887710381765, (6, 21)),
#  (8168.2887710381765, (21, 6)),
#  (8146.726451699567, (9, 12)),
#  (8146.726451699567, (12, 9)),
#  (8078.305419963312, (7, 23)),
#  (8078.305419963312, (23, 7)),
#  (8033.44061270529, (15, 19)),
#  (8033.44061270529, (19, 15)),
#  (7899.536099043493, (2, 20)),
#  (7899.536099043493, (20, 2)),
#  (7834.850712419735, (5, 24)),
#  (7834.850712419735, (24, 5)),
#  (7578.67758850678, (8, 11)),
#  (7578.67758850678, (11, 8)),
#  (7517.132635264373, (6, 25)),
#  (7517.132635264373, (25, 6)),
#  (7504.1611518782265, (5, 16)),
#  (7504.1611518782265, (16, 5)),
#  (7383.898823204074, (2, 24)),
#  (7383.898823204074, (24, 2)),
#  (7372.263352601143, (18, 23)),
#  (7372.263352601143, (23, 18)),
#  (7337.589244661142, (3, 12)),
#  (7337.589244661142, (12, 3)),
#  (7253.153513366495, (10, 14)),
#  (7253.153513366495, (14, 10)),
#  (7191.477064500599, (20, 21)),
#  (7191.477064500599, (21, 20)),
#  (6990.827044762862, (3, 15)),
#  (6990.827044762862, (15, 3)),
#  (6986.595385270655, (14, 17)),
#  (6986.595385270655, (17, 14)),
#  (6878.607033827835, (12, 17)),
#  (6878.607033827835, (17, 12)),
#  (6837.693762126373, (5, 9)),
#  (6837.693762126373, (9, 5)),
#  (6829.736688097151, (16, 22)),
#  (6829.736688097151, (22, 16)),
#  (6752.437339189713, (2, 7)),
#  (6752.437339189713, (7, 2)),
#  (6716.203258153673, (20, 25)),
#  (6716.203258153673, (25, 20)),
#  (6694.669634315096, (7, 22)),
#  (6694.669634315096, (22, 7)),
#  (6469.626054270317, (6, 14)),
#  (6469.626054270317, (14, 6)),
#  (6455.101679582756, (8, 13)),
#  (6455.101679582756, (13, 8)),
#  (6427.183314930138, (4, 18)),
#  (6427.183314930138, (18, 4)),
#  (6354.928273292087, (20, 22)),
#  (6354.928273292087, (22, 20)),
#  (6337.7528904319315, (6, 23)),
#  (6337.7528904319315, (23, 6)),
#  (6281.893763777406, (3, 6)),
#  (6281.893763777406, (6, 3)),
#  (6207.69543216533, (13, 18)),
#  (6207.69543216533, (18, 13)),
#  (6192.558784190902, (9, 21)),
#  (6192.558784190902, (21, 9)),
#  (6165.266895575123, (9, 22)),
#  (6165.266895575123, (22, 9)),
#  (6137.650527989679, (3, 21)),
#  (6137.650527989679, (21, 3)),
#  (6121.464499512738, (6, 9)),
#  (6121.464499512738, (9, 6)),
#  (6058.049459806007, (11, 19)),
#  (6058.049459806007, (19, 11)),
#  (6020.207157455148, (21, 24)),
#  (6020.207157455148, (24, 21)),
#  (5989.669100281022, (4, 8)),
#  (5989.669100281022, (8, 4)),
#  (5951.377380184887, (14, 25)),
#  (5951.377380184887, (25, 14)),
#  (5861.982800783773, (3, 10)),
#  (5861.982800783773, (10, 3)),
#  (5848.549928763539, (7, 15)),
#  (5848.549928763539, (15, 7)),
#  (5843.597600412697, (24, 25)),
#  (5843.597600412697, (25, 24)),
#  (5826.164584112048, (9, 10)),
#  (5826.164584112048, (10, 9)),
#  (5824.071922469317, (22, 24)),
#  (5824.071922469317, (24, 22)),
#  (5600.546826498379, (3, 5)),
#  (5600.546826498379, (5, 3)),
#  (5532.766900686231, (15, 20)),
#  (5532.766900686231, (20, 15)),
#  (5435.288588909693, (6, 16)),
#  (5435.288588909693, (16, 6)),
#  (5239.489711804603, (11, 18)),
#  (5239.489711804603, (18, 11)),
#  (5167.112018734748, (7, 21)),
#  (5167.112018734748, (21, 7)),
#  (5146.8958103579735, (3, 22)),
#  (5146.8958103579735, (22, 3)),
#  (5145.747959360691, (13, 19)),
#  (5145.747959360691, (19, 13)),
#  (5134.888796541913, (10, 20)),
#  (5134.888796541913, (20, 10)),
#  (5119.3089725601785, (16, 21)),
#  (5119.3089725601785, (21, 16)),
#  (5081.731934542378, (7, 25)),
#  (5081.731934542378, (25, 7)),
#  (4954.429470853767, (15, 24)),
#  (4954.429470853767, (24, 15)),
#  (4944.407755471133, (16, 17)),
#  (4944.407755471133, (17, 16)),
#  (4870.6368868283735, (3, 25)),
#  (4870.6368868283735, (25, 3)),
#  (4866.429209205406, (10, 16)),
#  (4866.429209205406, (16, 10)),
#  (4793.432410944748, (4, 19)),
#  (4793.432410944748, (19, 4)),
#  (4784.6358080767495, (9, 25)),
#  (4784.6358080767495, (25, 9)),
#  (4449.307686160446, (10, 24)),
#  (4449.307686160446, (24, 10)),
#  (4360.3471505610105, (2, 6)),
#  (4360.3471505610105, (6, 2)),
#  (4360.334029311423, (2, 18)),
#  (4360.334029311423, (18, 2)),
#  (4307.78486293417, (9, 17)),
#  (4307.78486293417, (17, 9)),
#  (4286.727889498698, (12, 18)),
#  (4286.727889498698, (18, 12)),
#  (4180.050456135734, (14, 23)),
#  (4180.050456135734, (23, 14)),
#  (3912.251618127935, (16, 25)),
#  (3912.251618127935, (25, 16)),
#  (3786.9863536395533, (7, 11)),
#  (3786.9863536395533, (11, 7)),
#  (3780.363339977459, (7, 10)),
#  (3780.363339977459, (10, 7)),
#  (3701.1430652967556, (4, 6)),
#  (3701.1430652967556, (6, 4)),
#  (3599.6897140848905, (8, 12)),
#  (3599.6897140848905, (12, 8)),
#  (3540.52152014469, (6, 13)),
#  (3540.52152014469, (13, 6)),
#  (3477.8545247496713, (3, 23)),
#  (3477.8545247496713, (23, 3)),
#  (3470.2943223845596, (3, 17)),
#  (3470.2943223845596, (17, 3)),
#  (3423.1097061223045, (15, 18)),
#  (3423.1097061223045, (18, 15)),
#  (3400.6495745936354, (2, 8)),
#  (3400.6495745936354, (8, 2)),
#  (3399.4899327020903, (11, 20)),
#  (3399.4899327020903, (20, 11)),
#  (3341.001469754641, (9, 23)),
#  (3341.001469754641, (23, 9)),
#  (3330.6664656195135, (8, 23)),
#  (3330.6664656195135, (23, 8)),
#  (3178.7798446269153, (4, 21)),
#  (3178.7798446269153, (21, 4)),
#  (3158.3722629550903, (12, 19)),
#  (3158.3722629550903, (19, 12)),
#  (3122.6026975271125, (2, 19)),
#  (3122.6026975271125, (19, 2)),
#  (3050.377564339855, (11, 24)),
#  (3050.377564339855, (24, 11)),
#  (2965.3140462739902, (13, 21)),
#  (2965.3140462739902, (21, 13)),
#  (2946.692510095505, (4, 10)),
#  (2946.692510095505, (10, 4)),
#  (2924.178653571067, (6, 11)),
#  (2924.178653571067, (11, 6)),
#  (2901.4257458230713, (7, 13)),
#  (2901.4257458230713, (13, 7)),
#  (2901.0533055809537, (19, 23)),
#  (2901.0533055809537, (23, 19)),
#  (2754.4070283894907, (10, 13)),
#  (2754.4070283894907, (13, 10)),
#  (2751.562707044978, (6, 12)),
#  (2751.562707044978, (12, 6)),
#  (2598.718175140524, (16, 23)),
#  (2598.718175140524, (23, 16)),
#  (2581.485928933311, (4, 7)),
#  (2581.485928933311, (7, 4)),
#  (2499.589369734069, (13, 20)),
#  (2499.589369734069, (20, 13)),
#  (2304.8869294480683, (5, 18)),
#  (2304.8869294480683, (18, 5)),
#  (2276.53324526659, (8, 14)),
#  (2276.53324526659, (14, 8)),
#  (2254.2030583666856, (13, 24)),
#  (2254.2030583666856, (24, 13)),
#  (2179.479054827818, (4, 20)),
#  (2179.479054827818, (20, 4)),
#  (2146.494062061278, (18, 22)),
#  (2146.494062061278, (22, 18)),
#  (2099.7346270355665, (11, 21)),
#  (2099.7346270355665, (21, 11)),
#  (2064.5317444033535, (4, 25)),
#  (2064.5317444033535, (25, 4)),
#  (2008.3840401269154, (10, 11)),
#  (2008.3840401269154, (11, 10)),
#  (1978.9003627424208, (4, 24)),
#  (1978.9003627424208, (24, 4)),
#  (1894.0134531468902, (13, 25)),
#  (1894.0134531468902, (25, 13)),
#  (1789.0713611306219, (6, 15)),
#  (1789.0713611306219, (15, 6)),
#  (1779.8139459898593, (10, 12)),
#  (1779.8139459898593, (12, 10)),
#  (1779.0474168877736, (14, 19)),
#  (1779.0474168877736, (19, 14)),
#  (1763.5800991991546, (2, 3)),
#  (1763.5800991991546, (3, 2)),
#  (1755.821632505942, (8, 16)),
#  (1755.821632505942, (16, 8)),
#  (1747.1670698973285, (12, 21)),
#  (1747.1670698973285, (21, 12)),
#  (1710.9657824781425, (2, 14)),
#  (1710.9657824781425, (14, 2)),
#  (1661.850570314924, (8, 25)),
#  (1661.850570314924, (25, 8)),
#  (1594.1661235127503, (2, 9)),
#  (1594.1661235127503, (9, 2)),
#  (1503.1403365178485, (7, 12)),
#  (1503.1403365178485, (12, 7)),
#  (1488.6071933340154, (19, 25)),
#  (1488.6071933340154, (25, 19)),
#  (1464.229082555059, (16, 19)),
#  (1464.229082555059, (19, 16)),
#  (1448.2324126772655, (8, 21)),
#  (1448.2324126772655, (21, 8)),
#  (1330.5998042945757, (8, 9)),
#  (1330.5998042945757, (9, 8)),
#  (1276.602589876653, (11, 25)),
#  (1276.602589876653, (25, 11)),
#  (1272.8212306039204, (19, 21)),
#  (1272.8212306039204, (21, 19)),
#  (1256.6165993584073, (6, 20)),
#  (1256.6165993584073, (20, 6)),
#  (1230.7264829968572, (12, 25)),
#  (1230.7264829968572, (25, 12)),
#  (1193.542693495856, (12, 20)),
#  (1193.542693495856, (20, 12)),
#  (1174.6500429276748, (2, 16)),
#  (1174.6500429276748, (16, 2)),
#  (1162.5371792001315, (12, 24)),
#  (1162.5371792001315, (24, 12)),
#  (1156.4242917053743, (2, 17)),
#  (1156.4242917053743, (17, 2)),
#  (1115.131060354639, (6, 24)),
#  (1115.131060354639, (24, 6)),
#  (1095.4044950412863, (9, 19)),
#  (1095.4044950412863, (19, 9)),
#  (1063.5390824505412, (5, 6)),
#  (1063.5390824505412, (6, 5)),
#  (1055.4474031844366, (6, 22)),
#  (1055.4474031844366, (22, 6)),
#  (986.9901003845516, (17, 18)),
#  (986.9901003845516, (18, 17)),
#  (986.1382780981075, (18, 20)),
#  (986.1382780981075, (20, 18)),
#  (985.507627194711, (8, 10)),
#  (985.507627194711, (10, 8)),
#  (969.2364876116153, (3, 8)),
#  (969.2364876116153, (8, 3)),
#  (955.9489424516032, (4, 23)),
#  (955.9489424516032, (23, 4)),
#  (898.503493018934, (10, 19)),
#  (898.503493018934, (19, 10)),
#  (845.347265599914, (6, 7)),
#  (845.347265599914, (7, 6)),
#  (834.5962130527623, (18, 24)),
#  (834.5962130527623, (24, 18)),
#  (832.8043598115219, (10, 15)),
#  (832.8043598115219, (15, 10)),
#  (827.264383133981, (13, 23)),
#  (827.264383133981, (23, 13)),
#  (801.2838272563276, (3, 19)),
#  (801.2838272563276, (19, 3)),
#  (783.865848712685, (15, 21)),
#  (783.865848712685, (21, 15)),
#  (779.4310549362563, (17, 23)),
#  (779.4310549362563, (23, 17)),
#  (566.3873439225208, (7, 18)),
#  (566.3873439225208, (18, 7)),
#  (542.5821296737649, (12, 23)),
#  (542.5821296737649, (23, 12)),
#  (424.69022371735264, (11, 23)),
#  (424.69022371735264, (23, 11)),
#  (416.79498876845173, (2, 5)),
#  (416.79498876845173, (5, 2)),
#  (384.9720922554552, (15, 25)),
#  (384.9720922554552, (25, 15)),
#  (351.28184832199986, (6, 17)),
#  (351.28184832199986, (17, 6)),
#  (304.7544981897008, (7, 14)),
#  (304.7544981897008, (14, 7)),
#  (288.24769623055, (2, 22)),
#  (288.24769623055, (22, 2)),
#  (278.1142506591568, (7, 16)),
#  (278.1142506591568, (16, 7)),
#  (273.88946930720704, (10, 22)),
#  (273.88946930720704, (22, 10)),
#  (249.70500757485206, (5, 10)),
#  (249.70500757485206, (10, 5)),
#  (207.90396457690804, (21, 22)),
#  (207.90396457690804, (22, 21)),
#  (200.72683276596217, (2, 4)),
#  (200.72683276596217, (4, 2)),
#  (182.5106124989543, (5, 21)),
#  (182.5106124989543, (21, 5)),
#  (149.74855962452057, (2, 13)),
#  (149.74855962452057, (13, 2)),
#  (129.46777072807527, (16, 24)),
#  (129.46777072807527, (24, 16)),
#  (127.2767160992571, (2, 12)),
#  (127.2767160992571, (12, 2)),
#  (123.28379582875277, (17, 25)),
#  (123.28379582875277, (25, 17)),
#  (121.38602696897578, (5, 23)),
#  (121.38602696897578, (23, 5)),
#  (119.38054802777333, (14, 24)),
#  (119.38054802777333, (24, 14)),
#  (118.8983253727638, (16, 20)),
#  (118.8983253727638, (20, 16)),
#  (109.7937735837113, (14, 20)),
#  (109.7937735837113, (20, 14)),
#  (109.76543928781393, (7, 9)),
#  (109.76543928781393, (9, 7)),
#  (62.75462215991138, (2, 15)),
#  (62.75462215991138, (15, 2)),
#  (58.978087423663965, (22, 25)),
#  (58.978087423663965, (25, 22)),
#  (56.567069515105686, (22, 23)),
#  (56.567069515105686, (23, 22)),
#  (39.67970749020242, (6, 19)),
#  (39.67970749020242, (19, 6)),
#  (35.90296257018417, (5, 25)),
#  (35.90296257018417, (25, 5)),
#  (35.49598018164397, (3, 7)),
#  (35.49598018164397, (7, 3)),
#  (33.66366188057873, (6, 8)),
#  (33.66366188057873, (8, 6)),
#  (31.59274083701166, (2, 11)),
#  (31.59274083701166, (11, 2)),
#  (31.321516225834785, (17, 21)),
#  (31.321516225834785, (21, 17)),
#  (25.92465331745916, (9, 24)),
#  (25.92465331745916, (24, 9)),
#  (18.231835870901705, (9, 20)),
#  (18.231835870901705, (20, 9)),
#  (15.486740551576077, (15, 23)),
#  (15.486740551576077, (23, 15)),
#  (8.983762237770861, (8, 18)),
#  (8.983762237770861, (18, 8)),
#  (3.642403225763701, (18, 19)),
#  (3.642403225763701, (19, 18)),
#  (2.400630235533754, (10, 17)),
#  (2.400630235533754, (17, 10)),
#  (0.6695182295261475, (3, 24)),
#  (0.6695182295261475, (24, 3)),
#  (0.03656256294925697, (3, 20)),
#  (0.03656256294925697, (20, 3)),
#  (0.0, (1, 2)),
#  (0.0, (1, 3)),
#  (0.0, (1, 4)),
#  (0.0, (1, 5)),
#  (0.0, (1, 6)),
#  (0.0, (1, 7)),
#  (0.0, (1, 8)),
#  (0.0, (1, 9)),
#  (0.0, (1, 10)),
#  (0.0, (1, 11)),
#  (0.0, (1, 12)),
#  (0.0, (1, 13)),
#  (0.0, (1, 14)),
#  (0.0, (1, 15)),
#  (0.0, (1, 16)),
#  (0.0, (1, 17)),
#  (0.0, (1, 18)),
#  (0.0, (1, 19)),
#  (0.0, (1, 20)),
#  (0.0, (1, 21)),
#  (0.0, (1, 22)),
#  (0.0, (1, 23)),
#  (0.0, (1, 24)),
#  (0.0, (1, 25)),
#  (0.0, (2, 1)),
#  (0.0, (3, 1)),
#  (0.0, (4, 1)),
#  (0.0, (5, 1)),
#  (0.0, (6, 1)),
#  (0.0, (7, 1)),
#  (0.0, (8, 1)),
#  (0.0, (9, 1)),
#  (0.0, (10, 1)),
#  (0.0, (11, 1)),
#  (0.0, (12, 1)),
#  (0.0, (13, 1)),
#  (0.0, (14, 1)),
#  (0.0, (15, 1)),
#  (0.0, (16, 1)),
#  (0.0, (17, 1)),
#  (0.0, (18, 1)),
#  (0.0, (19, 1)),
#  (0.0, (20, 1)),
#  (0.0, (21, 1)),
#  (0.0, (22, 1)),
#  (0.0, (23, 1)),
#  (0.0, (24, 1)),
#  (0.0, (25, 1))]
