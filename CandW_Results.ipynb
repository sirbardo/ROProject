# %%
import os
from tabulate import tabulate

# %%
def get_table(path):
    table = []
    files = os.listdir(path)
    files.sort()
    for filename in files:
        
        if '.txt' not in filename:
            continue
        
        with open(path+filename,'r') as f:
            content = f.read()
        content = content.split('\n')
        of = float(content[0].split(' ')[2])
        time = float(content[1].split(' ')[3])+float(content[4].split(' ')[4])

        with open('Instances/'+filename,'r') as f:
            content = f.read()
        content = content.split('\n')
        n_of_customers = int(content[0])

        with open('DetailedSols/RPA_Solutions/Detailed_Solution_'+filename,'r') as f:
            content = f.read()
        content = content.split('\n')
        opt_val = float(content[8].split(' ')[3])
        gap = of - opt_val

        table.append([filename[0:2],n_of_customers,of,time,gap])
    
    return table

# %%
table1 = get_table('parallel_routes/')
print(tabulate(table1,headers=['instance name','customers','objective value','time','cost gap'],tablefmt='grid',stralign='right',numalign='decimal'))
with open('parallel_resuts.txt','w') as f:
    f.write(tabulate(table1,headers=['instance name','customers','objective value','time','cost gap'],tablefmt='grid',stralign='right',numalign='decimal'))
# Out:
# +-----------------+-------------+-------------------+------------+---------------+
# |   instance name |   customers |   objective value |       time |      cost gap |
# +=================+=============+===================+============+===============+
# |              A1 |          25 |            230915 |  0.0587132 |   1028.95     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              A2 |          25 |            187985 |  0.0478523 |   7866.32     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              A3 |          25 |            155796 |  0.0589402 |  -7608.59     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              A4 |          25 |            155796 |  0.0623591 |      0.408808 |
# +-----------------+-------------+-------------------+------------+---------------+
# |              B1 |          30 |            253735 |  0.0962811 |  14654.5      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              B2 |          30 |            211863 |  0.120157  |  13815        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              B3 |          30 |            196773 |  0.150424  |  27401.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C1 |          40 |            267740 |  0.323129  |  17183.7      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C2 |          40 |            228651 |  0.341356  |  13631        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C3 |          40 |            214949 |  0.362265  |  15602.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              C4 |          40 |            214949 |  0.363194  |  19582.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D1 |          38 |            336030 |  0.211552  |  13500.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D2 |          38 |            336030 |  0.221986  |  19322.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D3 |          38 |            268535 |  0.209285  |  29055.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              D4 |          38 |            220873 |  0.323693  |  15041.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              E1 |          45 |            244207 |  0.449855  |   5326.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              E2 |          45 |            234003 |  0.524428  |  21739.9      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              E3 |          45 |            234003 |  0.539677  |  27343.9      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F1 |          60 |            280442 |  1.67055   |  17268.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F2 |          60 |            280442 |  1.69058   |  15228.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F3 |          60 |            259441 |  1.80771   |  18320.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              F4 |          60 |            259441 |  1.86528   |  25579.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G1 |          57 |            310006 |  0.898861  |   3700.13     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G2 |          57 |            246063 |  0.968696  |    622.488    |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G3 |          57 |            240011 |  1.23034   |  10503.7      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G4 |          57 |            240011 |  1.15671   |   7489.67     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G5 |          57 |            228727 |  1.46817   |   6997.45     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              G6 |          57 |            220102 |  1.37272   |   6645.44     |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H1 |          68 |            317854 |  2.04272   |  48921.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H2 |          68 |            316953 |  2.03468   |  63588.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H3 |          68 |            316953 |  2.15116   |  69504.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H4 |          68 |            316953 |  2.12841   |  66732.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H5 |          68 |            316953 |  2.17128   |  70832.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              H6 |          68 |            316953 |  2.11711   |  67818.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I1 |          90 |            367960 |  5.84093   |  17713.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I2 |          90 |            349565 |  5.53508   |  39621.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I3 |          90 |            348293 |  5.99918   |  53786.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I4 |          90 |            348293 |  6.1369    |  52305.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              I5 |          90 |            348293 |  5.98456   |  47057.3      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J1 |          94 |            368847 |  6.70999   |  33840.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J2 |          94 |            349403 |  7.37341   |  38985.9      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J3 |          94 |            318985 |  9.03448   |  39765.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              J4 |          94 |            329386 |  8.2725    |  32852.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K1 |         113 |            441293 | 15.356     |  47221.7      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K2 |         113 |            448120 | 14.1477    |  85990.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K3 |         113 |            448120 | 14.3875    |  82426.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              K4 |         113 |            437779 | 14.0141    |  88829.2      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L1 |         150 |            500588 | 36.0052    |  82691.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L2 |         150 |            500588 | 36.1482    |  99359.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L3 |         150 |            500588 | 36.2838    |  97909.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L4 |         150 |            500588 | 36.6823    | 115952        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              L5 |         150 |            500588 | 36.3497    | 113023        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M1 |         125 |            451109 | 18.2935    |  52515.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M2 |         125 |            451109 | 18.5333    |  54191.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M3 |         125 |            454186 | 18.0416    |  78490        |
# +-----------------+-------------+-------------------+------------+---------------+
# |              M4 |         125 |            447824 | 17.5077    |  99684.1      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N1 |         150 |            457885 | 36.4611    |  49783.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N2 |         150 |            457885 | 36.513     |  49818.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N3 |         150 |            452203 | 38.2986    |  57864.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N4 |         150 |            452203 | 38.7481    |  57414.8      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N5 |         150 |            451729 | 39.4028    |  78252.6      |
# +-----------------+-------------+-------------------+------------+---------------+
# |              N6 |         150 |            451729 | 37.785     |  77969.6      |
# +-----------------+-------------+-------------------+------------+---------------+

# %%
table2 = get_table('sequential_routes/')
print(tabulate(table2,headers=['instance name','customers','objective value','time','cost gap'],tablefmt='grid',stralign='right',numalign='decimal'))
with open('sequential_resuts.txt','w') as f:
    f.write(tabulate(table2,headers=['instance name','customers','objective value','time','cost gap'],tablefmt='grid',stralign='right',numalign='decimal'))
# Out:
# +-----------------+-------------+-------------------+------------+------------+
# |   instance name |   customers |   objective value |       time |   cost gap |
# +=================+=============+===================+============+============+
# |              A1 |          25 |            236409 |  0.0473518 |    6523.46 |
# +-----------------+-------------+-------------------+------------+------------+
# |              A2 |          25 |            185005 |  0.0522289 |    4886.21 |
# +-----------------+-------------+-------------------+------------+------------+
# |              A3 |          25 |            186793 |  0.07304   |   23387.8  |
# +-----------------+-------------+-------------------+------------+------------+
# |              A4 |          25 |            186793 |  0.072958  |   30996.8  |
# +-----------------+-------------+-------------------+------------+------------+
# |              B1 |          30 |            242495 |  0.089999  |    3415.44 |
# +-----------------+-------------+-------------------+------------+------------+
# |              B2 |          30 |            253180 |  0.093354  |   55132.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              B3 |          30 |            200553 |  0.150889  |   31180.6  |
# +-----------------+-------------+-------------------+------------+------------+
# |              C1 |          40 |            286960 |  0.16052   |   36403.6  |
# +-----------------+-------------+-------------------+------------+------------+
# |              C2 |          40 |            249209 |  0.263037  |   34189.4  |
# +-----------------+-------------+-------------------+------------+------------+
# |              C3 |          40 |            222236 |  0.237844  |   22890.4  |
# +-----------------+-------------+-------------------+------------+------------+
# |              C4 |          40 |            222236 |  0.224077  |   26870.4  |
# +-----------------+-------------+-------------------+------------+------------+
# |              D1 |          38 |            343087 |  0.125759  |   20557.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              D2 |          38 |            343087 |  0.122163  |   26379.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              D3 |          38 |            253532 |  0.0995848 |   14053.2  |
# +-----------------+-------------+-------------------+------------+------------+
# |              D4 |          38 |            257180 |  0.197187  |   51348.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              E1 |          45 |            273237 |  0.256771  |   34357.1  |
# +-----------------+-------------+-------------------+------------+------------+
# |              E2 |          45 |            241505 |  0.706323  |   29241.8  |
# +-----------------+-------------+-------------------+------------+------------+
# |              E3 |          45 |            285063 |  0.635057  |   78404.1  |
# +-----------------+-------------+-------------------+------------+------------+
# |              F1 |          60 |            287818 |  0.91252   |   24645.1  |
# +-----------------+-------------+-------------------+------------+------------+
# |              F2 |          60 |            287818 |  0.948832  |   22605.1  |
# +-----------------+-------------+-------------------+------------+------------+
# |              F3 |          60 |            295168 |  1.07016   |   54048.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              F4 |          60 |            278675 |  1.13781   |   44814.2  |
# +-----------------+-------------+-------------------+------------+------------+
# |              G1 |          57 |            340431 |  0.394898  |   34124.6  |
# +-----------------+-------------+-------------------+------------+------------+
# |              G2 |          57 |            282401 |  0.726425  |   36959.5  |
# +-----------------+-------------+-------------------+------------+------------+
# |              G3 |          57 |            289358 |  0.782694  |   59851    |
# +-----------------+-------------+-------------------+------------+------------+
# |              G4 |          57 |            289358 |  0.794337  |   56837    |
# +-----------------+-------------+-------------------+------------+------------+
# |              G5 |          57 |            287296 |  1.02025   |   65565.7  |
# +-----------------+-------------+-------------------+------------+------------+
# |              G6 |          57 |            287539 |  0.812145  |   74081.8  |
# +-----------------+-------------+-------------------+------------+------------+
# |              H1 |          68 |            322757 |  1.14137   |   53823.9  |
# +-----------------+-------------+-------------------+------------+------------+
# |              H2 |          68 |            294962 |  1.7711    |   41596.6  |
# +-----------------+-------------+-------------------+------------+------------+
# |              H3 |          68 |            299725 |  2.45408   |   52275.9  |
# +-----------------+-------------+-------------------+------------+------------+
# |              H4 |          68 |            299725 |  2.44354   |   49503.9  |
# +-----------------+-------------+-------------------+------------+------------+
# |              H5 |          68 |            280218 |  3.15824   |   34096.8  |
# +-----------------+-------------+-------------------+------------+------------+
# |              H6 |          68 |            280218 |  3.1397    |   31082.8  |
# +-----------------+-------------+-------------------+------------+------------+
# |              I1 |          90 |            422435 |  3.00623   |   72189    |
# +-----------------+-------------+-------------------+------------+------------+
# |              I2 |          90 |            370708 |  4.75132   |   60764.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              I3 |          90 |            385540 |  4.60768   |   91033.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              I4 |          90 |            385540 |  4.454     |   89552.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              I5 |          90 |            385540 |  4.61126   |   84304.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              J1 |          94 |            401547 |  3.49872   |   66541.1  |
# +-----------------+-------------+-------------------+------------+------------+
# |              J2 |          94 |            358355 |  4.43745   |   47938.2  |
# +-----------------+-------------+-------------------+------------+------------+
# |              J3 |          94 |            347143 |  4.68691   |   67924    |
# +-----------------+-------------+-------------------+------------+------------+
# |              J4 |          94 |            358901 |  5.86251   |   62368.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              K1 |         113 |            491114 |  7.16905   |   97043.4  |
# +-----------------+-------------+-------------------+------------+------------+
# |              K2 |         113 |            404736 | 11.7664    |   42606    |
# +-----------------+-------------+-------------------+------------+------------+
# |              K3 |         113 |            404736 | 11.9578    |   39042    |
# +-----------------+-------------+-------------------+------------+------------+
# |              K4 |         113 |            434448 | 12.8429    |   85498.1  |
# +-----------------+-------------+-------------------+------------+------------+
# |              L1 |         150 |            602430 | 12.7576    |  184534    |
# +-----------------+-------------+-------------------+------------+------------+
# |              L2 |         150 |            523839 | 18.6068    |  122611    |
# +-----------------+-------------+-------------------+------------+------------+
# |              L3 |         150 |            523839 | 18.1708    |  121161    |
# +-----------------+-------------+-------------------+------------+------------+
# |              L4 |         150 |            512261 | 18.3521    |  127625    |
# +-----------------+-------------+-------------------+------------+------------+
# |              L5 |         150 |            512261 | 17.9462    |  124696    |
# +-----------------+-------------+-------------------+------------+------------+
# |              M1 |         125 |            471400 |  9.98693   |   72806.6  |
# +-----------------+-------------+-------------------+------------+------------+
# |              M2 |         125 |            471400 | 10.1662    |   74482.6  |
# +-----------------+-------------+-------------------+------------+------------+
# |              M3 |         125 |            471834 |  7.76233   |   96138.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              M4 |         125 |            407519 | 14.3015    |   59378.6  |
# +-----------------+-------------+-------------------+------------+------------+
# |              N1 |         150 |            492194 | 25.7391    |   84093.4  |
# +-----------------+-------------+-------------------+------------+------------+
# |              N2 |         150 |            492194 | 26.566     |   84128.4  |
# +-----------------+-------------+-------------------+------------+------------+
# |              N3 |         150 |            487170 | 25.1775    |   92832.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              N4 |         150 |            487170 | 25.6396    |   92382.3  |
# +-----------------+-------------+-------------------+------------+------------+
# |              N5 |         150 |            459351 | 34.3806    |   85875    |
# +-----------------+-------------+-------------------+------------+------------+
# |              N6 |         150 |            459351 | 33.3279    |   85592    |
# +-----------------+-------------+-------------------+------------+------------+
